# %% [markdown]
# # Pattern Matching Problem: Find all occurrences of a pattern in a string.

# %% [markdown]
# Input: Strings Pattern and Genome.
#
#  Output: All starting positions in Genome where Pattern appears as a substring.

# %% [markdown]
# Sample Input:
# ATAT;;;;;;
# GATATATGCATATACTT
#
# Sample Output:
# 1 3 9

# %%
def PatternMatching(Pattern, Genome):
    positions = [] # output variable
    for i in range(len(Genome)-len(Pattern)+1):
        if Genome[i:i+len(Pattern)] == Pattern :
            positions.append(i)
    return positions

PatternMatching("ATAT","GATATATGCATATACTT")
# Out:
# [1, 3, 9]

# %% [markdown]
# ---

# %%
def PatternMatching(Pattern, Genome):
    positions = [] # output variable
    for i in range(len(Genome)-len(Pattern)+1):
        if Genome[i:i+len(Pattern)] == Pattern :
            positions.append(i)
    return positions

#PatternMatching("TTACGTCTT","...")
print(*PatternMatching("GGCGAGTGG", "..."), sep=' ')
#print(*pattern_matching(pattern, genome), sep=' ') , this will remove [] and ,
# Out:
# 8 15 32 100 117 132 140 175 182 213 245 252 259 330 409 449 478 502 509 651 684 708 733 781 800 832 884 891 906 913 920 959 986 993 1043 1050 1057 1065 1084 1138 1146 1153 1192 1209 1227 1238 1245 1267 1274 1281 1288 1296 1412 1428 1451 1558 1596 1624 1735 1759 1766 1773 1780 1823 1836 1843 1850 1862 1869 1876 1941 1949 2018 2025 2044 2124 2133 2154 2179 2197 2225 2232 2239 2344 2351 2371 2397 2404 2425 2432 2440 2456 2482 2512 2538 2546 2562 2569 2597 2604 2677 2705 2791 2798 2826 2833 2870 2877 2884 2957 2973 2991 3007 3022 3037 3123 3193 3288 3333 3341 3415 3453 3469 3476 3519 3526 3549 3623 3630 3637 3644 3664 3680 3709 3730 3737 3744 3751 3758 3789 3829 3836 3862 3886 3953 3972 3979 3996 4003 4010 4017 4024 4138 4153 4160 4194 4201 4211 4218 4257 4264 4271 4281 4288 4323 4330 4338 4372 4379 4415 4469 4487 4494 4518 4566 4573 4580 4665 4685 4711 4742 4786 4793 4824 4831 4839 4869 4888 4895 4903 4932 4939 4946 4963 5046 5082 5089 5123 5139 5163 5179 5223 5257 5268 5275 5282 5307 5
# ...

# %%
def PatternMatching(Pattern, Genome):
    positions = [] # output variable
    for i in range(len(Genome)-len(Pattern)+1):
        if Genome[i:i+len(Pattern)] == Pattern :
            positions.append(i)
    return positions

print(*PatternMatching("AA"," AAACATAGGATCAAC"),sep = " ")
# Out:
# 1 2 13
